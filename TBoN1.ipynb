# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          90 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
conda install beautifulsoup4
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2s             |       h7b6447c_0         3.1 MB
#     beautifulsoup4-4.7.1       |           py36_1         143 KB
#     soupsieve-1.9.2            |           py36_0          61 KB
#     certifi-2019.6.16          |           py36_1         156 KB
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     soupsieve:      1.9.2-py36_0
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.3-py37_0                  --> 4.7.1-py36_1
#     certifi:        2019.6.16-py36_1  conda-forge --> 2019.6.16-py36_1
#     openssl:        1.0.2r-h14c3975_0 conda-forge --> 1.0.2s-h7b6447c_0
#
#
# Downloading and Extracting Packages
# openssl-1.0.2s       | 3.1 MB    | ##################################### | 100%
# beautifulsoup4-4.7.1 | 143 KB    | ##################################### | 100%
# soupsieve-1.9.2      | 61 KB     | ##################################### | 100%
# certifi-2019.6.16    | 156 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install lxml
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     lxml-4.3.0                 |   py36hefd8a0e_0         1.5 MB
#
# The following packages will be UPDATED:
#
#     lxml: 4.2.5-py37hefd8a0e_0 --> 4.3.0-py36hefd8a0e_0
#
#
# Downloading and Extracting Packages
# lxml-4.3.0           | 1.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install html5lib
# Out:
# Solving environment: /
# Warning: 2 possible package resolutions (only showing differing packages):
#   - conda-forge::html5lib-0.9999999-py36_0
#   - defaults::html5lib-0.9999999-py36done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install requests
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-2.22.0            |           py36_0          89 KB
#     urllib3-1.24.2             |           py36_0         153 KB
#     ------------------------------------------------------------
#                                            Total:         242 KB
#
# The following packages will be DOWNGRADED:
#
#     requests: 2.22.0-py36_1 conda-forge --> 2.22.0-py36_0
#     urllib3:  1.25.3-py36_0 conda-forge --> 1.24.2-py36_0
#
#
# Downloading and Extracting Packages
# requests-2.22.0      | 89 KB     | ##################################### | 100%
# urllib3-1.24.2       | 153 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### After importing the required libraries, we get the data from Wikipedia website and format it into a table

# %%
source=requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text

# %%
import numpy as np
import pandas as pd

# %%
soup=BeautifulSoup(source,'lxml')

# %%
table_soup=soup.table.tbody.find_all('tr')

# %%
table_soup.remove(table_soup[0])

# %%
pc=list()
br=list()
ne=list()
for row in table_soup:
    try:
        pc.append(row.find_all('td')[0].text)
        br.append(row.find_all('td')[1].text)
        ne.append(row.find_all('td')[2].text.strip())
    except Exception as e:
        pass
toronto_df=pd.DataFrame({'Postalcode':pc,'Borough':br,'Neighborhood':ne})

# %%
df= toronto_df

# %% [markdown]
# #### This is the table obtained

# %%
toronto_df.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### We drop the values of Borough which are 'Not assigned'

# %%
toronto_df=toronto_df.drop(toronto_df[toronto_df['Borough']=='Not assigned'].index)

# %%
toronto_df.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M5A  Downtown Toronto       Regent Park
# 6        M6A        North York  Lawrence Heights

# %%
toronto_df.loc[toronto_df['Neighborhood']=='Not assigned','Neighborhood']=toronto_df.loc[toronto_df['Neighborhood']=='Not assigned','Borough']

# %%
toronto_gr=toronto_df.groupby("Postalcode")

# %%
df=pd.DataFrame(columns=['Postalcode','Borough','Neighborhood'])
i=0
for grp in pd.unique(toronto_df["Postalcode"]):
    ni=list()
    grp_df=toronto_gr.get_group(grp)
    ni=grp_df['Neighborhood'].values
    #temp_df=pd.DataFrame({'Postalcode':[grp],'Borough':pd.unique(grp_df['Borough']),'Neighborhood':','.join(ni)})
    #print(temp_df)
    df.loc[i]=[grp,pd.unique(grp_df['Borough'])[0],','.join(ni)]
    i=i+1
df.head()
# Out:
#   Postalcode           Borough                     Neighborhood
# 0        M3A        North York                        Parkwoods
# 1        M4A        North York                 Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park
# 3        M6A        North York  Lawrence Heights,Lawrence Manor
# 4        M7A      Queen's Park                     Queen's Park

# %% [markdown]
# #### The shape of the required table is given:

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Using the CSV file to create the required dataframe

# %%
# !wget -o 'toranto_geodata.csv' https://cocl.us/Geospatial_data
data=pd.read_csv('https://cocl.us/Geospatial_data')
data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
lat_arr=list()
lon_arr=list()
for postal_code in df['Postalcode'].values:
    lat_arr.append(data.loc[data['Postal Code']==postal_code,'Latitude'].values[0])
    lon_arr.append(data.loc[data['Postal Code']==postal_code,'Longitude'].values[0])
df['Latitude']=lat_arr
df['Longitude']=lon_arr
df.head()
# Out:
#   Postalcode           Borough                     Neighborhood   Latitude  \
# 0        M3A        North York                        Parkwoods  43.753259
# 1        M4A        North York                 Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4        M7A      Queen's Park                     Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# ### The above dataframe is the required dataframe

# %% [markdown]
# ## Exploring and clustering the neighborhoods in Toronto

# %%
pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 16.3MB/s ta 0:00:01
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.22.0)
# Collecting future (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
#      |████████████████████████████████| 829kB 32.6MB/s eta 0:00:01
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Collecting click (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 15.7MB/s eta 0:00:01
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2019.6.16)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/0c/61/d2/d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
# Successfully built future
# Installing collected packages: ratelim, future, click, geocoder
# Successfully installed click-7.0 future-0.17.1 geocoder-1.38.1 ratelim-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[43.651070, -79.347015], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'P32HI1KGPKTUQAQOD3VO01BHUGIDM52JB2BFMTBUIHJZWKHH' # your Foursquare ID
CLIENT_SECRET = '043WTYCNXVJK3CW5VAUP5ODDOS3MMZZ4H5Q0PXF3S0NEZJUS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
print(df['Neighborhood'].values[0],df['Postalcode'].values[0])
# Out:
# Parkwoods M3A

# %%
print('latitude :',df['Latitude'].values[0])
print('longitude:',df['Longitude'].values[0])
# Out:
# latitude : 43.7532586
# longitude: -79.3296565

# %% [markdown]
# ### Now, let's get the top 100 venues that are in Parkwoods M3A within a radius of 2 Km.

# %%
LIMIT=100
radius=2000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    43.7532586, 
    -79.3296565, 
    radius, 
    LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=P32HI1KGPKTUQAQOD3VO01BHUGIDM52JB2BFMTBUIHJZWKHH&client_secret=043WTYCNXVJK3CW5VAUP5ODDOS3MMZZ4H5Q0PXF3S0NEZJUS&v=20180605&ll=43.7532586,-79.3296565&radius=2000&limit=100'

# %%
import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
results = requests.get(url).json()

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                           name            categories        lat        lng
# 0              Allwyn's Bakery  Caribbean Restaurant  43.759840 -79.324719
# 1  Donalda Golf & Country Club           Golf Course  43.752816 -79.342741
# 2              Brookbanks Park                  Park  43.751976 -79.332140
# 3                 Island Foods  Caribbean Restaurant  43.745866 -79.346035
# 4           Graydon Hall Manor           Event Space  43.763923 -79.342961

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 88 venues were returned by Foursquare.

# %%
res2=results['response']['groups'][0]['items']
for res in res2:
    print(res['venue']['name'])
    print("     at a distance of---> ",res['venue']['location']['distance'])
    print()
print()
# Out:
# Allwyn's Bakery
#      at a distance of--->  833
#
# Donalda Golf & Country Club
#      at a distance of--->  1053
#
# Brookbanks Park
#      at a distance of--->  245
#
# Island Foods
#      at a distance of--->  1553
#
# Graydon Hall Manor
#      at a distance of--->  1597
#
# Darband Restaurant
#      at a distance of--->  1530
#
# LA Fitness
#      at a distance of--->  1532
#
# Galleria Supermarket
#      at a distance of--->  1597
#
# Tim Hortons
#      at a distance of--->  866
#
# LCBO
#      at a distance of--->  1336
#
# Me Va Me Kitchen Express
#      at a distance of--->  1798
#
# North Beach Indoor Volleyball Academy
#      at a distance of--->  1851
#
# Baretto Caffé
#      at a distance of--->  1669
#
# Matsuda Japanese Cuisine & Teppanyaki
#      at a distance of--->  1561
#
# A&W Canada
#      at a distance of--->  852
#
# Gilaneh
#      at a distance of--->  1639
#
# Spoon And Fork Plus
#      at a distance of--->  1614
#
# Casa Manila
#      at a distance of--->  1561
#
# Tim Hortons
#      at a distance of--->  1254
#
# The Captain's Boil
#      at a distance of--->  1609
#
# Georgy Porgy's
#      at a distance of--->  1767
#
# Menchie's Frozen Yogurt
#      at a distance of--->  1645
#
# Pizzaiolo
#      at a distance of--->  1652
#
# Baskin Robbins
#      at a distance of--->  1756
#
# Omni Palace Noodle House
#      at a distance of--->  1986
#
# David Duncan House
#      at a distance of--->  1643
#
# Dragon Pearl Buffet 龍珠
#      at a distance of--->  1614
#
# The Westin Prince, Toronto
#      at a distance of--->  1714
#
# Shooters Snooker & Sports Club
#      at a distance of--->  1783
#
# Paisano
#      at a distance of--->  1612
#
# Aroma Espresso Bar
#      at a distance of--->  1968
#
# Dollarama
#      at a distance of--->  1620
#
# China Gourmet
#      at a distance of--->  1520
#
# Five Guys
#      at a distance of--->  1662
#
# The Bean Sprout
#      at a distance of--->  1783
#
# Starbucks
#      at a distance of--->  1776
#
# GoodLife Fitness North York Victoria Terrace
#      at a distance of--->  1795
#
# Rexall
#      at a distance of--->  1530
#
# Bruno's valu-mart
#      at a distance of--->  882
#
# Food Basics
#      at a distance of--->  895
#
# Tim Hortons
#      at a distance of--->  1503
#
# China Cottage
#      at a distance of--->  1677
#
# Staples
#      at a distance of--->  1627
#
# The Beer Store
#      at a distance of--->  1398
#
# TD Canada Trust
#      at a distance of--->  1462
#
# Shoppers Drug Mart
#      at a distance of--->  937
#
# Thai One On
#      at a distance of--->  1765
#
# Gonoe Sushi
#      at a distance of--->  1557
#
# Freshii
#      at a distance of--->  1772
#
# Subway
#      at a distance of--->  1486
#
# Tim Hortons
#      at a distance of--->  1558
#
# Popeyes Louisiana Kitchen
#      at a distance of--->  1599
#
# High Street Fish & Chips
#      at a distance of--->  967
#
# Shoppers Drug Mart
#      at a distance of--->  926
#
# Tim Hortons
#      at a distance of--->  1494
#
# Tim Hortons
#      at a distance of--->  1778
#
# Second Cup
#      at a distance of--->  1518
#
# Cora Breakfast and Lunch
#      at a distance of--->  1753
#
# Subway
#      at a distance of--->  1545
#
# Popeyes Louisiana Kitchen
#      at a distance of--->  1591
#
# Pizza Pizza
#      at a distance of--->  839
#
# TD Canada Trust
#      at a distance of--->  1274
#
# Shoppers Drug Mart
#      at a distance of--->  1390
#
# Katsura Japanese Restaurant 桂
#      at a distance of--->  1635
#
# City Chevrolet Buick Cadillac GMC Ltd.
#      at a distance of--->  1775
#
# MR. GREEK Express
#      at a distance of--->  1776
#
# Variety Store
#      at a distance of--->  312
#
# Popeyes Louisiana Kitchen
#      at a distance of--->  1812
#
# William Ashley Sale
#      at a distance of--->  1737
#
# TTC Stop #09083
#      at a distance of--->  741
#
# TTC Stop 9083
#      at a distance of--->  752
#
# Fox & Fiddle
#      at a distance of--->  1655
#
# Wild Wing
#      at a distance of--->  1260
#
# Toys"R"Us
#      at a distance of--->  1734
#
# Pizza Hut
#      at a distance of--->  1767
#
# Metro
#      at a distance of--->  1338
#
# Dollarama
#      at a distance of--->  1728
#
# Subway
#      at a distance of--->  1560
#
# Sushi Ichiban
#      at a distance of--->  1640
#
# Teriyaki Experience
#      at a distance of--->  1755
#
# Lynedock Park
#      at a distance of--->  1248
#
# Tim Hortons / Esso
#      at a distance of--->  1492
#
# Dollarama
#      at a distance of--->  1555
#
# Mayur Fine Indian Cuisine
#      at a distance of--->  1652
#
# Timothy's World Coffee
#      at a distance of--->  1822
#
# CBS - Toronto Bible Store
#      at a distance of--->  1791
#
# Bond Park
#      at a distance of--->  1945
#
# Lawrence & Victoria Park
#      at a distance of--->  1992

# %%
map_parkwoods=folium.Map(location=[43.7532586,-79.3296565],zoom_start=13)
map_parkwoods
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for res in res2:
    latit=res['venue']['location']['lat']
    longit=res['venue']['location']['lng']
    label=res['venue']['name']
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [latit, longit],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color='#36FEF8',
        fill_opacity=0.7,
        parse_html=False).add_to(map_parkwoods)
map_parkwoods
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_clustered=pd.DataFrame(columns=['venue','latitude','longitude','venue_type'])
for res in res2:
    latit=res['venue']['location']['lat']
    longit=res['venue']['location']['lng']
    label=res['venue']['name']
    name=res['venue']['categories'][0]['name']
    df_clustered=df_clustered.append({'venue':label,'latitude':latit,'longitude':longit,'venue_type':name},ignore_index=True)
df_clustered.head(9)
# Out:
#                          venue   latitude  longitude  \
# 0              Allwyn's Bakery  43.759840 -79.324719
# 1  Donalda Golf & Country Club  43.752816 -79.342741
# 2              Brookbanks Park  43.751976 -79.332140
# 3                 Island Foods  43.745866 -79.346035
# 4           Graydon Hall Manor  43.763923 -79.342961
# 5           Darband Restaurant  43.755194 -79.348498
# 6                   LA Fitness  43.747665 -79.347077
# 7         Galleria Supermarket  43.753520 -79.349518
# 8                  Tim Hortons  43.760668 -79.326368
#
#                   venue_type
# 0       Caribbean Restaurant
# 1                Golf Course
# 2                       Park
# 3       Caribbean Restaurant
# 4                Event Space
# 5  Middle Eastern Restaurant
# 6       Gym / Fitness Center
# 7                Supermarket
# 8                       Café

# %% [markdown]
# ### Clustering Neighborhood

# %%
from sklearn.cluster import KMeans

# %%
kclusters=5
kmeans = KMeans(n_clusters=kclusters, random_state=0)
kmeans.fit(df_clustered[['latitude','longitude']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
df_clustered['cluster']=kmeans.labels_

# %%
df_clustered.head()
# Out:
#                          venue   latitude  longitude            venue_type  \
# 0              Allwyn's Bakery  43.759840 -79.324719  Caribbean Restaurant
# 1  Donalda Golf & Country Club  43.752816 -79.342741           Golf Course
# 2              Brookbanks Park  43.751976 -79.332140                  Park
# 3                 Island Foods  43.745866 -79.346035  Caribbean Restaurant
# 4           Graydon Hall Manor  43.763923 -79.342961           Event Space
#
#    cluster
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_clusters=folium.Map(location=[43.7532586,-79.3296565],zoom_start=13)

markers_colors = []
for lat, lon, poi, cluster in zip(df_clustered['latitude'], df_clustered['longitude'], df_clustered['venue'], df_clustered['cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Lets assume that the person wants to set up a Coffee Shop

# %%
cluster=df_clustered['cluster'].value_counts().index
count=df_clustered['cluster'].value_counts().values
btype_count=list()
for i in cluster:
    btype_count.append(sum(1 for p in ((df_clustered[df_clustered['cluster']==i]['venue_type']=='Coffee Shop').values) if p==True))
df_clustered_btype=pd.DataFrame({'cluster':cluster,'count':count,'btype_count':btype_count})
df_clustered_btype
# Out:
#    cluster  count  btype_count
# 0        1     37            2
# 1        3     15            3
# 2        2     14            2
# 3        4     12            0
# 4        0     10            3

# %% [markdown]
# #### We can see that there are Coffee Shops located in all clusters except Cluster 4

# %%
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

map_clusters=folium.Map(location=[43.7532586,-79.3296565],zoom_start=14)

markers_colors = []
for lat, lon, poi, cluster,venue_type in zip(df_clustered['latitude'], df_clustered['longitude'], df_clustered['venue'], df_clustered['cluster'],df_clustered['venue_type']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    if venue_type=='Supermarket':
        folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.9).add_to(map_clusters)
    else:
        folium.CircleMarker(
        [lat, lon],
        radius=2,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.4).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_clustered_btype_fil=df_clustered_btype[df_clustered_btype['count']==df_clustered_btype['count'].max()]
df_clustered_btype_fil
# Out:
#    cluster  count  btype_count
# 0        1     37            2

# %%
kmeans.cluster_centers_[3]
# Out:
# array([ 43.75769766, -79.31260234])

# %% [markdown]
# #### The best suitable cluster to start a Coffee Shop in "Parkwoods" is cluster 4

# %% [markdown]
# ###  Thank you
# ### - A.V.R.Jatin
